# %% [markdown]
# # Import the pandas library

# %%
import pandas as pd

# %% [markdown]
# # Import Data Set

# %% [markdown]
# Raw: https://www.kaggle.com/datasets/uciml/student-alcohol-consumption?resource=download

# %% [markdown]
# With Total Alcohol: https://sooners-my.sharepoint.com/:x:/g/personal/brooke_tumelson1_ou_edu/ERB2NGhlcihDnEmu7guYAvsBU4JxeITabP4YuroKYk-8BA?rtime=L8WROVLE2kg

# %%
alcoholanalysis = pd.read_csv("Happiness.Alcohol.Consumption.csv")

# %% [markdown]
# # View Data Set

# %%
alcoholanalysis
# Out:
#          Country                           Region Hemisphere  HappinessScore  \
# 0        Denmark                   Western Europe      north           7.526
# 1    Switzerland                   Western Europe      north           7.509
# 2        Iceland                   Western Europe      north           7.501
# 3         Norway                   Western Europe      north           7.498
# 4        Finland                   Western Europe      north           7.413
# ..           ...                              ...        ...             ...
# 117     Tanzania               Sub-Saharan Africa      south           3.666
# 118      Liberia               Sub-Saharan Africa      north           3.622
# 119        Benin               Sub-Saharan Africa      north           3.484
# 120         Togo               Sub-Saharan Africa      north           3.303
# 121        Syria  Middle East and Northern Africa      north           3.069
#
# ...

# %%
alcoholanalysis.head()
# Out:
#        Country          Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0      Denmark  Western Europe      north           7.526  928         53.579
# 1  Switzerland  Western Europe      north           7.509  943         79.866
# 2      Iceland  Western Europe      north           7.501  933         60.530
# 3       Norway  Western Europe      north           7.498  951         70.890
# 4      Finland  Western Europe      north           7.413  918         43.433
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita  TotalAlcohol_PerCapita
# 0             224                81             278              397.666667
# 1             185               100             280              378.333333
# 2             233                61              78              320.000000
# 3             169                71             129              283.000000
# 4             263               133              97              428.333333

# %%
alcoholanalysis.tail()
# Out:
#       Country                           Region Hemisphere  HappinessScore  \
# 117  Tanzania               Sub-Saharan Africa      south           3.666
# 118   Liberia               Sub-Saharan Africa      north           3.622
# 119     Benin               Sub-Saharan Africa      north           3.484
# 120      Togo               Sub-Saharan Africa      north           3.303
# 121     Syria  Middle East and Northern Africa      north           3.069
#
#      HDI  GDP_PerCapita  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita  \
# 117  533        878.000              36                 6               1
# 118  432        455.000              19               152               2
# 119  512        789.000              34                 4              13
# 120  500        577.000              36                 2              19
# 121  536          2.058               5                35              16
#
#      TotalAlcohol_PerCapita
# 117               42.333333
# ...

# %%
alcoholanalysis.describe()
# Out:
#        HappinessScore         HDI  GDP_PerCapita  Beer_PerCapita  \
# count      122.000000  122.000000     122.000000      122.000000
# mean         5.524828  740.877049      91.482836      137.565574
# std          1.148736  149.846124     209.577313      104.817353
# min          3.069000  351.000000       1.029000        1.000000
# 25%          4.528250  663.750000       4.134250       38.250000
# 50%          5.542000  757.500000      12.016000      125.500000
# 75%          6.477000  861.500000      41.990000      224.750000
# max          7.526000  951.000000     953.000000      376.000000
#
#        Spirit_PerCapita  Wine_PerCapita  TotalAlcohol_PerCapita
# count        122.000000      122.000000              122.000000
# mean          96.598361       66.598361              256.363388
# std           81.435028       88.121503              167.923361
# min            1.000000        1.000000                4.333333
# ...

# %% [markdown]
# # Import Libraries for Plotting

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Pairplot of the Data

# %%
#With outliers: 
sns.pairplot(alcoholanalysis, x_vars=['HDI', 'GDP_PerCapita', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita'], y_vars='HappinessScore', height=5, aspect =0.7, kind='reg')
plt.show()
